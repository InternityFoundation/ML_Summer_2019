# %% [markdown]
# # look at Random Forest for Classification¶

# %% [markdown]
# # Problem Definition

# %% [markdown]
# The task here is to predict whether a bank currency note is authentic or not based on four attributes.

# %%
import pandas as pd  
import numpy as np

# %%
dataset1 = pd.read_csv("bill_authentication.csv")

# %%
dataset1.head()
# Out:
#    Variance  Skewness  Curtosis  Entropy  Class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %% [markdown]
# # Preparing Data For Training

# %%
X = dataset1.iloc[:, 0:4].values  
y = dataset1.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# We know our dataset is not yet a scaled value, for instance the Average_Income field has values in the range of thousands while Petrol_tax has values in range of tens. Therefore, it would be beneficial to scale our data (although, as mentioned earlier,
# this step isn't as important for the random forests algorithm).

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()  
X_train = sc.fit_transform(X_train)  
X_test = sc.transform(X_test)

# %% [markdown]
# # Training the Algorithm

# %%
from sklearn.ensemble import  RandomForestClassifier

classifier = RandomForestClassifier(n_estimators=20, random_state=0)  
classifier.fit(X_train, y_train)  
y_pred = classifier.predict(X_test)

# %% [markdown]
# # Now the time to Evaluate our Model (Accuracy)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(y_test,y_pred))  
print(classification_report(y_test,y_pred))  
print(accuracy_score(y_test, y_pred))
# Out:
# [[155   2]
#  [  1 117]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       157
#            1       0.98      0.99      0.99       118
#
#    micro avg       0.99      0.99      0.99       275
#    macro avg       0.99      0.99      0.99       275
# weighted avg       0.99      0.99      0.99       275
#
# 0.9890909090909091
