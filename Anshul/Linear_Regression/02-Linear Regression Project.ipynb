# %%
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
ecom=pd.read_csv('Ecommerce Customers')

# %%
ecom.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
ecom.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Email                   500 non-null object
# Address                 500 non-null object
# Avatar                  500 non-null object
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 25.4+ KB

# %%
sns.set_style("whitegrid")
sns.jointplot(x=ecom['Time on Website'],y=ecom['Yearly Amount Spent'],data=ecom,xlim=(33,41),ylim=(200,800))

plt.tight_layout()

# %%
sns.jointplot(x=ecom['Time on App'],y=ecom['Yearly Amount Spent'],data=ecom)

# %%
sns.jointplot(x=ecom['Time on App'],y=ecom['Length of Membership'],data=ecom,kind='hex')

# %%
sns.pairplot(ecom)

# %%
sns.lmplot('Time on App','Yearly Amount Spent',ecom)

# %%
fig,axes=plt.subplots(ncols=4,figsize=(15,6))
sns.regplot('Time on App','Yearly Amount Spent',ecom,ax=axes[0])
sns.regplot('Time on Website','Yearly Amount Spent',ecom,ax=axes[1])
sns.regplot('Length of Membership','Yearly Amount Spent',ecom,ax=axes[2])
sns.regplot('Avg. Session Length','Yearly Amount Spent',ecom,ax=axes[3])
fig.tight_layout()

# %%
X=ecom[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
y=ecom['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.coef_
# Out:
# array([25.98154972, 38.59015875,  0.19040528, 61.27909654])

# %%
coef=pd.DataFrame(lm.coef_,X.columns,columns=['Coeff'])
coef
# Out:
#                           Coeff
# Avg. Session Length   25.981550
# Time on App           38.590159
# Time on Website        0.190405
# Length of Membership  61.279097

# %%
predictions=lm.predict(X_test)
plt.scatter(y_test,predictions)

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 7.22814865343
# MSE: 79.813051651
# RMSE: 8.93381506698

# %%
sns.distplot(y_test-predictions,bins=50)

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                       Coeffecient
# Avg. Session Length     25.981550
# Time on App             38.590159
# Time on Website          0.190405
# Length of Membership    61.279097
